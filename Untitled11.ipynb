# %%
import pandas as pd

# %%
dataset = '/content/WLD_RTFP_country_2023-10-02.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM  2023-06-01
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM  2023-07-01
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM  2023-08-01
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM  2023-09-01
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM  2023-10-01
#
# [4798 rows x 8 columns]

# %%
data.head()
# Out:
#    Open  High   Low  Close  Inflation      country ISO3        date
# 0  0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1  0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2  0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3  0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4  0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01

# %%
print(data.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Inflation    float64
# country       object
# ISO3          object
# date          object
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#       Open  High   Low  Close      country ISO3        date
# 0     0.53  0.54  0.53   0.53  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...          ...  ...         ...
# 4793  2.74  2.78  2.70   2.75  Yemen, Rep.  YEM  2023-06-01
# 4794  2.79  2.83  2.75   2.81  Yemen, Rep.  YEM  2023-07-01
# 4795  2.85  2.89  2.81   2.83  Yemen, Rep.  YEM  2023-08-01
# 4796  2.86  2.97  2.82   2.97  Yemen, Rep.  YEM  2023-09-01
# 4797  3.06  3.11  2.98   2.98  Yemen, Rep.  YEM  2023-10-01
#
# [4798 rows x 7 columns]

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Inflation
# count  4734.000000  4734.000000  4734.000000  4734.000000  4434.000000
# mean      1.491880     1.536158     1.451056     1.492398    14.692346
# std       4.652457     4.883312     4.439229     4.633321    35.910342
# min       0.010000     0.010000     0.010000     0.010000   -31.470000
# 25%       0.740000     0.750000     0.720000     0.740000    -0.487500
# 50%       0.960000     0.980000     0.950000     0.960000     5.360000
# 75%       1.100000     1.120000     1.077500     1.100000    16.372500
# max     102.460000   106.480000    94.420000    94.420000   363.100000

# %%
data.loc[:,"Open":].corr()
# Out:
# <ipython-input-17-e76634f051a8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"Open":].corr()
#                Open      High       Low     Close  Inflation
# Open       1.000000  0.998958  0.999731  0.997202   0.362280
# High       0.998958  1.000000  0.998734  0.998961   0.362110
# Low        0.999731  0.998734  1.000000  0.997874   0.363067
# Close      0.997202  0.998961  0.997874  1.000000   0.364800
# Inflation  0.362280  0.362110  0.363067  0.364800   1.000000

# %%
# @title Low vs Inflation

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Low', y='Inflation', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Dengan API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-904d4980-bd9d-4c34-ba65-58c2779d3491" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-904d4980-bd9d-4c34-ba65-58c2779d3491">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "food and drink"
# Out:
# ...
# ref                                                           title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# anasfikrihanif/indonesian-food-and-drink-nutrition-dataset    Indonesian Food and Drink Nutrition Dataset         74KB  2023-10-31 16:34:34            842         36  1.0
# fuarresvij/jakarta-food-and-drinks-culinary-business          Jakarta Food and Drinks Culinary Business 2014     135KB  2022-11-17 06:05:06            455         21  0.9411765
# starbucks/starbucks-menu                                      Nutrition facts for Starbucks Menu                   9KB  2017-07-20 21:49:50          20714        186  0.85294116
# ...

# %%
# !kaggle datasets download anasfikrihanif/indonesian-food-and-drink-nutrition-dataset
# Out:
# ...
#   0% 0.00/73.7k [00:00<?, ?B/s]
# 100% 73.7k/73.7k [00:00<00:00, 68.6MB/s]

# %%
# !unzip /content/indonesian-food-and-drink-nutrition-dataset.zip
# Out:
# Archive:  /content/indonesian-food-and-drink-nutrition-dataset.zip
#   inflating: nutrition.csv

# %%
pd.read_csv('/content/nutrition.csv')
# Out:
#         id  calories  proteins   fat  carbohydrate                name  \
# 0        1     280.0       9.2  28.4           0.0                Abon
# 1        2     513.0      23.7  37.0          21.3        Abon haruwan
# 2        3       0.0       0.0   0.2           0.0           Agar-agar
# 3        4      45.0       1.1   0.4          10.8  Akar tonjong segar
# 4        5      37.0       4.4   0.5           3.8       Aletoge segar
# ...    ...       ...       ...   ...           ...                 ...
# 1341  1342      42.0       1.2   0.6           9.3        Wortel Segar
# 1342  1343      37.0       1.0   0.6           8.3        Wortel kukus
# 1343  1344      28.0       0.7   0.5           6.3        Wortel rebus
# 1344  1345     254.0       3.0   1.1          58.1              Yangko
# 1345  1346      52.0       3.3   2.5           4.0             Yoghurt
#
#                                                   image
# 0     https://img-cdn.medkomtek.com/PbrY9X3ignQ8sVuj...
# ...
